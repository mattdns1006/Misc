# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.animation as animation
# %matplotlib nbagg

# %%
def func(x1):
    return 1.2*((x1-2)**2)

def dfunc(x1):
    return 2.4*(x1-2)

xt = np.random.uniform(-30,30) #Initial guess

fxt = func(xt)
dfxt = dfunc(xt)
xt -= lr*dfxt

def animate(i):
    line.set_ydata(np.sin(x+i/10.0))  # update the data
    return line,

fig, ax = plt.subplots()

line, = ax.plot(xt,fxt)
# Out:
# <img src="data:image/png;base64,...">

# %%
xt = None
x = np.arange(-30,30,0.01)
y = func(x)
lr = 0.01

for t in range(100):
    
    if t ==0:
        xt = np.random.uniform(-30,30) #Initial guess
    
    fxt = func(xt)
    dfxt = dfunc(xt)
    xt -= lr*dfxt
    
    if t % 10 == 0:
        plt.plot(x,y)
        plt.title("step %d with lr = %f current value %f and gradient %f" % (t,lr,fxt,dfxt))
        plt.plot(xt,fxt,"ro")
        plt.plot(2,func(2),"bo")
        plt.show()

# %%
def rosenbrock(x1,x2,b):
    return (1-x1**2)  + b*((x2-x1**2)**2)

def dRosenbrock(x1,x2,b):
    pdRosenbrockx1 = -2 + 2*x1 - 2*b*x1*(x2-x1**2)
    pdRosenbrockx2 = 2*b*(x2-x1**2)
    return np.array([pdRosenbrockx1, pdRosenbrockx2])

# %%
interval = 0.04
start, fin = -5, 5
x,y = np.arange(start,fin,interval), np.arange(start,fin,interval)

# %%
b = 1
xt = np.random.uniform(-1,1,2) #Initial guess
fxt = rosenbrock(xt[0],xt[1],b)
xz
dRosenbrock(1,1,b)
# Out:
# array([0, 0])

# %%
X, Y = np.meshgrid(x,y)
Z = rosenbrock(X,Y,b)
lr = 0.05
for t in range(200):
    
    if t == 0:
        xt = np.random.uniform(-2,-1.4,2) #Initial guess
    
            
    
    fxt = rosenbrock(xt[0],xt[1],b)
    dfxt = dRosenbrock(xt[0],xt[1],b)
    
    
    if t % 10 == 0:
        #plt.plot(x,y)
        #plt.title("step %d with lr = %f current value %s and gradient %s" % (t,lr,fxt,dfxt))
        plt.plot(xt[0],xt[1],"ro")

        plt.contour(X,Y,Z)
        plt.show()

    
    #print(dfxt,fxt)
    xt -= lr*dfxt
